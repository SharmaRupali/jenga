# %%
import warnings
warnings.filterwarnings('ignore')

import pickle

import sys
sys.path.append('/home/rupali/Documents/Master Thesis/jenga')

# %%
import random
import numpy as np
import pandas as pd

from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

from jenga.basis import Dataset
from jenga.corruptions.generic import MissingValues, SwappedValues, CategoricalShift
from jenga.corruptions.numerical import Scaling, GaussianNoise
from jenga.cleaning.ppp import PipelinePerformancePrediction
from jenga.cleaning.outlier_detection import NoOutlierDetection, PyODKNNOutlierDetection, PyODIsolationForestOutlierDetection, PyODPCAOutlierDetection, PyODCBLOFOutlierDetection, PyODSOSOutlierDetection, SklearnOutlierDetection
from jenga.cleaning.imputation import MeanModeImputation, SklearnImputation, DatawigImputation
from jenga.cleaning.clean import Clean

import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

# %%
## use categorical columns as strings
def cat_cols_to_str(df):
    for col in df.columns:
        if pd.api.types.is_categorical_dtype(df[col]):
            df[col] = df[col].astype(str)

    return df
# Out:
# /home/rupali/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def run_experiment(dataset_name, learner, param_grid, corruptions, fraction, cleaners, num_repetitions, categorical_precision_threshold=0.85, numerical_std_error_threshold=0.9):
    
    ## dataset
    dataset = Dataset(dataset_name)
    
    all_data = dataset.all_data
    attribute_names = dataset.attribute_names
    attribute_types = dataset.attribute_types
    
    ## categorical and numerical features
    categorical_columns = dataset.categorical_columns
    numerical_columns = dataset.numerical_columns
    print(f"Found {len(categorical_columns)} categorical and {len(numerical_columns)} numeric features \n")
    
    ## train and test data
    df_train, lab_train, df_test, lab_test = dataset.get_train_test_data()
    ### if we don't convert the categorical columns to str, the swapping corruption doesn't let us assign new values to the column: "Cannot setitem on a Categorical with a new category, set the categories first"
    df_train = cat_cols_to_str(df_train)
    df_test = cat_cols_to_str(df_test)
    
    ## pipeline performance prediction (ppp)
    ppp = PipelinePerformancePrediction(df_train, lab_train, df_test, lab_test, categorical_columns, numerical_columns, learner, param_grid)
    ppp_model = ppp.fit_ppp(df_train)
    ## the class column is added to the training data for Autogluon model fit
    if learner == None:
        df_train = df_train.loc[:, df_train.columns != 'class']
    
    ## generate corrupted data
    for _ in range(num_repetitions):
        df_corrupted, perturbations, cols_perturbed, summary_col_corrupt = ppp.get_corrupted(df_test, corruptions, fraction, num_repetitions)
    
    ## cleaning
    clean = Clean(df_train, df_corrupted, categorical_columns, numerical_columns, categorical_precision_threshold, numerical_std_error_threshold, ppp, ppp_model, cleaners)
    df_outliers, df_cleaned, corrupted_score_ppp, best_cleaning_score, cleaner_scores_ppp, summary_cleaners = clean(df_train, df_test, df_corrupted, cols_perturbed)
    
    ## results
    result = {
        'ppp_score_model': ppp.predict_score_ppp(ppp_model, df_test),
        'ppp_score_corrupted': corrupted_score_ppp,
        'ppp_score_cleaned': best_cleaning_score,
        'ppp_scores_cleaners': cleaner_scores_ppp
    }
    
    ## summary
    summary = {
        'dataset': dataset_name,
        'model': learner,
        'corruptions': summary_col_corrupt,
        'cleaners': summary_cleaners,
        'result': result
    }
    
    return summary #summary_col_corrupt, result

# %%
def save_obj(obj, name):
    with open('/home/rupali/Documents/Master Thesis/jenga/results/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open('/home/rupali/Documents/Master Thesis/jenga/results/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
datasets = [
    'thoracic_surgery',
    'cleve',
    'acute-inflammations',
    'hill-valley'
]

# %%
## model parameters
## models is a dict where key = leaner & value = param_grid
models = {SGDClassifier(loss='log'): {'learner__max_iter': [500, 1000, 5000], 
                                         'learner__penalty': ['l2', 'l1', 'elasticnet'], 
                                         'learner__alpha': [0.0001, 0.001, 0.01, 0.1]
                                        },
          RandomForestClassifier():{'learner__n_estimators': [100, 200, 500], 
                                    'learner__max_depth': [5, 10, 15]
                                   },
          None:None
         }

## make dict of multiple leraners and corresponding param_grids

# %%
fractions = [0.15, 0.25, 0.5, 0.75, 0.9]

# %%
cleaners = []
for od in [NoOutlierDetection, PyODKNNOutlierDetection, PyODIsolationForestOutlierDetection, PyODPCAOutlierDetection, PyODCBLOFOutlierDetection, PyODSOSOutlierDetection, SklearnOutlierDetection]:
    for imp in [MeanModeImputation, SklearnImputation, DatawigImputation]:
        cleaners.append((od, imp))

# %% [markdown]
# ## Gaussian

# %%
corruptions = [[GaussianNoise]]

# %%
ind_results = {}

for fraction in fractions:
    ind_results[fraction] = []
    for learner, param_grid in models.items():
        for corruption in corruptions:
            for dataset in datasets:
                try:
                    ind_results[fraction].append(run_experiment(dataset, learner, param_grid, corruption, fraction, cleaners, 5))
                except ConnectionError:
                    print(f'Connection refused for dataset: {dataset}')
                    continue
                except ValueError:
                    print("Something went wrong with a value :(")
                    continue
# Out:
# Starting [get] request for the URL https://www.openml.org/api/v1/xml/data/list/limit/10000/offset/0/status/active/data_name/thoracic_surgery
# 2021-04-19 01:06:11,931 [INFO]  Starting [get] request for the URL https://www.openml.org/api/v1/xml/data/list/limit/10000/offset/0/status/active/data_name/thoracic_surgery
# 0.2469578s taken for [get] request for the URL https://www.openml.org/api/v1/xml/data/list/limit/10000/offset/0/status/active/data_name/thoracic_surgery
# 2021-04-19 01:06:12,179 [INFO]  0.2469578s taken for [get] request for the URL https://www.openml.org/api/v1/xml/data/list/limit/10000/offset/0/status/active/data_name/thoracic_surgery
# pickle load data thoracic_surgery
# 2021-04-19 01:06:12,195 [INFO]  pickle load data thoracic_surgery
# NumExpr defaulting to 4 threads.
# 2021-04-19 01:06:12,216 [INFO]  NumExpr defaulting to 4 threads.
# Dataset: thoracic_surgery
# Found 13 categorical and 3 numeric features
#
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:    3.4s finished
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# Generating corrupted training data on 94 rows...
#
# 	perturbation: GaussianNoise: {'column': 'PRE5', 'fraction': 0.15, 'sampling': 'MAR'}
#
# Generating corrupted training data on 94 rows...
#
# 	perturbation: GaussianNoise: {'column': 'PRE5', 'fraction': 0.15, 'sampling': 'MNAR'}
#
# Generating corrupted training data on 94 rows...
#
# 	perturbation: GaussianNoise: {'column': 'PRE5', 'fraction': 0.15, 'sampling': 'MAR'}
#
# Generating corrupted training data on 94 rows...
#
# 	perturbation: GaussianNoise: {'column': 'AGE', 'fraction': 0.15, 'sampling': 'MCAR'}
#
# Generating corrupted training data on 94 rows...
#
# 	perturbation: GaussianNoise: {'column': 'PRE4', 'fraction': 0.15, 'sampling': 'MCAR'}
#
# Applying cleaners...
#
# PPP score no cleaning: {'roc_auc_score': 0.5017543859649123, 'classification_report': {'F': {'precision': 0.797752808988764, 'recall': 0.9466666666666667, 'f1-score': 0.8658536585365854, 'support': 75}, 'T': {'precision': 0.2, 'recall': 0.05263157894736842, 'f1-score': 0.08333333333333333, 'support': 19}, 'accuracy': 0.7659574468085106, 'macro avg': {'precision': 0.498876404494382, 'recall': 0.49964912280701756, 'f1-score': 0.47459349593495936, 'support': 94}, 'weighted avg': {'precision': 0.676930432703801, 'recall': 0.7659574468085106, 'f1-score': 0.7076846566338003, 'support': 94}}}
# PPP scores with cleaning:
#
# Outlier detection method: NoOutlierDetection, Outlier Detection Score: {'Precision': 0.425531914893617, 'Recall': 0.5, 'F1-score': 0.4597701149425288, 'Accuracy': 0.851063829787234}
# Imputation method: MeanModeImputation, Imputation Score: {'Precision': nan, 'Recall': nan, 'F1-score': nan, 'Accuracy': nan, 'Mean Squared Error': 1.500081422710122}
# Cleaner: (NoOutlierDetection, MeanModeImputation): {'roc_auc_score': 0.4743859649122807, 'classification_report': {'F': {'precision': 0.7931034482758621, 'recall': 0.92, 'f1-score': 0.851851851851852, 'support': 75}, 'T': {'precision': 0.14285714285714285, 'recall': 0.05263157894736842, 'f1-score': 0.07692307692307693, 'support': 19}, 'accuracy': 0.7446808510638298, 'macro avg': {'precision': 0.46798029556650245, 'recall': 0.48631578947368426, 'f1-score': 0.4643874643874645, 'support': 94}, 'weighted avg': {'precision': 0.6616706844146316, 'recall': 0.7446808510638298, 'f1-score': 0.695217312238589, 'support': 94}}}
# Classifier for col: DGN reached 0.69
# Classifier for col: PRE6 reached 0.8266666666666667
# Classifier for col: PRE7 reached 0.9299999999999999
# Classifier for col: PRE8 reached 0.8333333333333334
# Classifier for col: PRE9 reached 0.9333333333333333
# Classifier for col: PRE10 reached 0.8633333333333333
# Classifier for col: PRE11 reached 0.8300000000000001
# Classifier for col: PRE14 reached 0.48
# Classifier for col: PRE17 reached 0.9333333333333333
# Classifier for col: PRE19 reached nan
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# Classifier for col: PRE25 reached 0.97
# Classifier for col: PRE30 reached 0.8133333333333332
# Classifier for col: PRE32 reached 0.9866666666666666
# Regressor for col: PRE4/lower reached 0.2263164087891963
# Regressor for col: PRE4/median reached 0.6922809325135914
# Regressor for col: PRE4/upper reached 0.4576467283411829
# Regressor for col: PRE5/lower reached -0.037137180801056324
# Regressor for col: PRE5/median reached -0.05062477702933377
# Regressor for col: PRE5/upper reached -0.5287667963683063
# Regressor for col: AGE/lower reached -0.7877976973292447
# Regressor for col: AGE/median reached 0.08800932475682721
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# CategoricalEncoder for column DGN                                found only 37 occurrences of value DGN2
# 2021-04-19 01:06:26,708 [INFO]  CategoricalEncoder for column DGN                                found only 37 occurrences of value DGN2
# CategoricalEncoder for column DGN                                found only 37 occurrences of value DGN4
# 2021-04-19 01:06:26,709 [INFO]  CategoricalEncoder for column DGN                                found only 37 occurrences of value DGN4
# CategoricalEncoder for column DGN                                found only 9 occurrences of value DGN5
# 2021-04-19 01:06:26,711 [INFO]  CategoricalEncoder for column DGN                                found only 9 occurrences of value DGN5
# CategoricalEncoder for column DGN                                found only 3 occurrences of value DGN6
# 2021-04-19 01:06:26,713 [INFO]  CategoricalEncoder for column DGN                                found only 3 occurrences of value DGN6
# CategoricalEncoder for column DGN                                found only 1 occurrences of value DGN1
# 2021-04-19 01:06:26,714 [INFO]  CategoricalEncoder for column DGN                                found only 1 occurrences of value DGN1
# Regressor for col: AGE/upper reached -1.1968498733376893
#
# Outlier detection method: NoOutlierDetection, Outlier Detection Score: {'Precision': 0.425531914893617, 'Recall': 0.5, 'F1-score': 0.4597701149425288, 'Accuracy': 0.851063829787234}
# Imputation method: SklearnImputation, Imputation Score: {'Precision': nan, 'Recall': nan, 'F1-score': nan, 'Accuracy': nan, 'Mean Squared Error': 1.500081422710122}
# Cleaner: (NoOutlierDetection, SklearnImputation): {'roc_auc_score': 0.4743859649122807, 'classification_report': {'F': {'precision': 0.7931034482758621, 'recall': 0.92, 'f1-score': 0.851851851851852, 'support': 75}, 'T': {'precision': 0.14285714285714285, 'recall': 0.05263157894736842, 'f1-score': 0.07692307692307693, 'support': 19}, 'accuracy': 0.7446808510638298, 'macro avg': {'precision': 0.46798029556650245, 'recall': 0.48631578947368426, 'f1-score': 0.4643874643874645, 'support': 94}, 'weighted avg': {'precision': 0.6616706844146316, 'recall': 0.7446808510638298, 'f1-score': 0.695217312238589, 'support': 94}}}
# Fitting model for column: DGN
# Test set does not contain any ocurrences of values [DGN1] in column [DGN], consider using a more representative test set.
# 2021-04-19 01:06:26,995 [WARNING]  Test set does not contain any ocurrences of values [DGN1] in column [DGN], consider using a more representative test set.
#
# ========== start: fit model
# 2021-04-19 01:06:27,003 [INFO]
# ========== start: fit model
# Already bound, ignoring bind()
# 2021-04-19 01:06:27,004 [WARNING]  Already bound, ignoring bind()
# Epoch[0] Batch [0-11]	Speed: 1261.71 samples/sec	cross-entropy=1.383834	DGN-accuracy=0.661458
# 2021-04-19 01:06:27,182 [INFO]  Epoch[0] Batch [0-11]	Speed: 1261.71 samples/sec	cross-entropy=1.383834	DGN-accuracy=0.661458
# Epoch[0] Train-cross-entropy=1.103991
# 2021-04-19 01:06:27,347 [INFO]  Epoch[0] Train-cross-entropy=1.103991
# Epoch[0] Train-DGN-accuracy=0.724432
# 2021-04-19 01:06:27,348 [INFO]  Epoch[0] Train-DGN-accuracy=0.724432
# Epoch[0] Time cost=0.336
# 2021-04-19 01:06:27,350 [INFO]  Epoch[0] Time cost=0.336
# Saved checkpoint to "imputer_model/model-0000.params"
# 2021-04-19 01:06:27,357 [INFO]  Saved checkpoint to "imputer_model/model-0000.params"
# Epoch[0] Validation-cross-entropy=0.753086
# 2021-04-19 01:06:27,401 [INFO]  Epoch[0] Validation-cross-entropy=0.753086
# Epoch[0] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:27,403 [INFO]  Epoch[0] Validation-DGN-accuracy=0.791667
# Epoch[1] Batch [0-11]	Speed: 1040.37 samples/sec	cross-entropy=0.955098	DGN-accuracy=0.713542
# 2021-04-19 01:06:27,591 [INFO]  Epoch[1] Batch [0-11]	Speed: 1040.37 samples/sec	cross-entropy=0.955098	DGN-accuracy=0.713542
# Epoch[1] Train-cross-entropy=0.850196
# 2021-04-19 01:06:27,736 [INFO]  Epoch[1] Train-cross-entropy=0.850196
# Epoch[1] Train-DGN-accuracy=0.747159
# 2021-04-19 01:06:27,738 [INFO]  Epoch[1] Train-DGN-accuracy=0.747159
# Epoch[1] Time cost=0.335
# 2021-04-19 01:06:27,739 [INFO]  Epoch[1] Time cost=0.335
# Saved checkpoint to "imputer_model/model-0001.params"
# 2021-04-19 01:06:27,750 [INFO]  Saved checkpoint to "imputer_model/model-0001.params"
# Epoch[1] Validation-cross-entropy=0.751785
# 2021-04-19 01:06:27,793 [INFO]  Epoch[1] Validation-cross-entropy=0.751785
# Epoch[1] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:27,795 [INFO]  Epoch[1] Validation-DGN-accuracy=0.791667
# Epoch[2] Batch [0-11]	Speed: 1039.38 samples/sec	cross-entropy=0.888541	DGN-accuracy=0.703125
# 2021-04-19 01:06:27,989 [INFO]  Epoch[2] Batch [0-11]	Speed: 1039.38 samples/sec	cross-entropy=0.888541	DGN-accuracy=0.703125
# Epoch[2] Train-cross-entropy=0.801972
# 2021-04-19 01:06:28,130 [INFO]  Epoch[2] Train-cross-entropy=0.801972
# Epoch[2] Train-DGN-accuracy=0.747159
# 2021-04-19 01:06:28,132 [INFO]  Epoch[2] Train-DGN-accuracy=0.747159
# Epoch[2] Time cost=0.337
# 2021-04-19 01:06:28,134 [INFO]  Epoch[2] Time cost=0.337
# Saved checkpoint to "imputer_model/model-0002.params"
# 2021-04-19 01:06:28,143 [INFO]  Saved checkpoint to "imputer_model/model-0002.params"
# Epoch[2] Validation-cross-entropy=0.733986
# 2021-04-19 01:06:28,190 [INFO]  Epoch[2] Validation-cross-entropy=0.733986
# Epoch[2] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:28,192 [INFO]  Epoch[2] Validation-DGN-accuracy=0.791667
# Epoch[3] Batch [0-11]	Speed: 1192.39 samples/sec	cross-entropy=0.866634	DGN-accuracy=0.713542
# 2021-04-19 01:06:28,364 [INFO]  Epoch[3] Batch [0-11]	Speed: 1192.39 samples/sec	cross-entropy=0.866634	DGN-accuracy=0.713542
# Epoch[3] Train-cross-entropy=0.792590
# 2021-04-19 01:06:28,535 [INFO]  Epoch[3] Train-cross-entropy=0.792590
# Epoch[3] Train-DGN-accuracy=0.750000
# 2021-04-19 01:06:28,536 [INFO]  Epoch[3] Train-DGN-accuracy=0.750000
# Epoch[3] Time cost=0.344
# 2021-04-19 01:06:28,538 [INFO]  Epoch[3] Time cost=0.344
# Saved checkpoint to "imputer_model/model-0003.params"
# 2021-04-19 01:06:28,546 [INFO]  Saved checkpoint to "imputer_model/model-0003.params"
# Epoch[3] Validation-cross-entropy=0.721231
# 2021-04-19 01:06:28,593 [INFO]  Epoch[3] Validation-cross-entropy=0.721231
# Epoch[3] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:28,595 [INFO]  Epoch[3] Validation-DGN-accuracy=0.791667
# Epoch[4] Batch [0-11]	Speed: 1169.17 samples/sec	cross-entropy=0.852225	DGN-accuracy=0.713542
# 2021-04-19 01:06:28,773 [INFO]  Epoch[4] Batch [0-11]	Speed: 1169.17 samples/sec	cross-entropy=0.852225	DGN-accuracy=0.713542
# Epoch[4] Train-cross-entropy=0.782671
# 2021-04-19 01:06:28,950 [INFO]  Epoch[4] Train-cross-entropy=0.782671
# Epoch[4] Train-DGN-accuracy=0.750000
# 2021-04-19 01:06:28,952 [INFO]  Epoch[4] Train-DGN-accuracy=0.750000
# Epoch[4] Time cost=0.356
# 2021-04-19 01:06:28,953 [INFO]  Epoch[4] Time cost=0.356
# Saved checkpoint to "imputer_model/model-0004.params"
# 2021-04-19 01:06:28,959 [INFO]  Saved checkpoint to "imputer_model/model-0004.params"
# Epoch[4] Validation-cross-entropy=0.715302
# 2021-04-19 01:06:28,999 [INFO]  Epoch[4] Validation-cross-entropy=0.715302
# Epoch[4] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:29,001 [INFO]  Epoch[4] Validation-DGN-accuracy=0.791667
# Epoch[5] Batch [0-11]	Speed: 1006.55 samples/sec	cross-entropy=0.840848	DGN-accuracy=0.713542
# 2021-04-19 01:06:29,201 [INFO]  Epoch[5] Batch [0-11]	Speed: 1006.55 samples/sec	cross-entropy=0.840848	DGN-accuracy=0.713542
# Epoch[5] Train-cross-entropy=0.775178
# 2021-04-19 01:06:29,359 [INFO]  Epoch[5] Train-cross-entropy=0.775178
# Epoch[5] Train-DGN-accuracy=0.750000
# 2021-04-19 01:06:29,361 [INFO]  Epoch[5] Train-DGN-accuracy=0.750000
# Epoch[5] Time cost=0.359
# 2021-04-19 01:06:29,363 [INFO]  Epoch[5] Time cost=0.359
# Saved checkpoint to "imputer_model/model-0005.params"
# 2021-04-19 01:06:29,372 [INFO]  Saved checkpoint to "imputer_model/model-0005.params"
# Epoch[5] Validation-cross-entropy=0.710311
# 2021-04-19 01:06:29,414 [INFO]  Epoch[5] Validation-cross-entropy=0.710311
# Epoch[5] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:29,416 [INFO]  Epoch[5] Validation-DGN-accuracy=0.791667
# Epoch[6] Batch [0-11]	Speed: 1011.35 samples/sec	cross-entropy=0.833980	DGN-accuracy=0.713542
# 2021-04-19 01:06:29,613 [INFO]  Epoch[6] Batch [0-11]	Speed: 1011.35 samples/sec	cross-entropy=0.833980	DGN-accuracy=0.713542
# Epoch[6] Train-cross-entropy=0.770483
# 2021-04-19 01:06:29,748 [INFO]  Epoch[6] Train-cross-entropy=0.770483
# Epoch[6] Train-DGN-accuracy=0.750000
# 2021-04-19 01:06:29,750 [INFO]  Epoch[6] Train-DGN-accuracy=0.750000
# Epoch[6] Time cost=0.334
# 2021-04-19 01:06:29,752 [INFO]  Epoch[6] Time cost=0.334
# Saved checkpoint to "imputer_model/model-0006.params"
# 2021-04-19 01:06:29,758 [INFO]  Saved checkpoint to "imputer_model/model-0006.params"
# Epoch[6] Validation-cross-entropy=0.707441
# 2021-04-19 01:06:29,798 [INFO]  Epoch[6] Validation-cross-entropy=0.707441
# Epoch[6] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:29,800 [INFO]  Epoch[6] Validation-DGN-accuracy=0.791667
# Epoch[7] Batch [0-11]	Speed: 1178.92 samples/sec	cross-entropy=0.827998	DGN-accuracy=0.713542
# 2021-04-19 01:06:29,973 [INFO]  Epoch[7] Batch [0-11]	Speed: 1178.92 samples/sec	cross-entropy=0.827998	DGN-accuracy=0.713542
# Epoch[7] Train-cross-entropy=0.765848
# 2021-04-19 01:06:30,144 [INFO]  Epoch[7] Train-cross-entropy=0.765848
# Epoch[7] Train-DGN-accuracy=0.750000
# 2021-04-19 01:06:30,145 [INFO]  Epoch[7] Train-DGN-accuracy=0.750000
# Epoch[7] Time cost=0.345
# 2021-04-19 01:06:30,147 [INFO]  Epoch[7] Time cost=0.345
# Saved checkpoint to "imputer_model/model-0007.params"
# 2021-04-19 01:06:30,157 [INFO]  Saved checkpoint to "imputer_model/model-0007.params"
# Epoch[7] Validation-cross-entropy=0.705188
# 2021-04-19 01:06:30,200 [INFO]  Epoch[7] Validation-cross-entropy=0.705188
# Epoch[7] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:30,201 [INFO]  Epoch[7] Validation-DGN-accuracy=0.791667
# Epoch[8] Batch [0-11]	Speed: 1004.01 samples/sec	cross-entropy=0.823110	DGN-accuracy=0.713542
# 2021-04-19 01:06:30,402 [INFO]  Epoch[8] Batch [0-11]	Speed: 1004.01 samples/sec	cross-entropy=0.823110	DGN-accuracy=0.713542
# Epoch[8] Train-cross-entropy=0.761953
# 2021-04-19 01:06:30,552 [INFO]  Epoch[8] Train-cross-entropy=0.761953
# Epoch[8] Train-DGN-accuracy=0.750000
# 2021-04-19 01:06:30,553 [INFO]  Epoch[8] Train-DGN-accuracy=0.750000
# Epoch[8] Time cost=0.352
# 2021-04-19 01:06:30,555 [INFO]  Epoch[8] Time cost=0.352
# Saved checkpoint to "imputer_model/model-0008.params"
# 2021-04-19 01:06:30,561 [INFO]  Saved checkpoint to "imputer_model/model-0008.params"
# Epoch[8] Validation-cross-entropy=0.703255
# 2021-04-19 01:06:30,604 [INFO]  Epoch[8] Validation-cross-entropy=0.703255
# Epoch[8] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:30,607 [INFO]  Epoch[8] Validation-DGN-accuracy=0.791667
# Epoch[9] Batch [0-11]	Speed: 997.45 samples/sec	cross-entropy=0.818952	DGN-accuracy=0.713542
# 2021-04-19 01:06:30,810 [INFO]  Epoch[9] Batch [0-11]	Speed: 997.45 samples/sec	cross-entropy=0.818952	DGN-accuracy=0.713542
# Epoch[9] Train-cross-entropy=0.758553
# 2021-04-19 01:06:30,959 [INFO]  Epoch[9] Train-cross-entropy=0.758553
# Epoch[9] Train-DGN-accuracy=0.750000
# 2021-04-19 01:06:30,961 [INFO]  Epoch[9] Train-DGN-accuracy=0.750000
# Epoch[9] Time cost=0.353
# 2021-04-19 01:06:30,963 [INFO]  Epoch[9] Time cost=0.353
# Saved checkpoint to "imputer_model/model-0009.params"
# 2021-04-19 01:06:30,972 [INFO]  Saved checkpoint to "imputer_model/model-0009.params"
# Epoch[9] Validation-cross-entropy=0.701743
# 2021-04-19 01:06:31,015 [INFO]  Epoch[9] Validation-cross-entropy=0.701743
# Epoch[9] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:31,016 [INFO]  Epoch[9] Validation-DGN-accuracy=0.791667
# Epoch[10] Batch [0-11]	Speed: 994.74 samples/sec	cross-entropy=0.815286	DGN-accuracy=0.713542
# 2021-04-19 01:06:31,214 [INFO]  Epoch[10] Batch [0-11]	Speed: 994.74 samples/sec	cross-entropy=0.815286	DGN-accuracy=0.713542
# Epoch[10] Train-cross-entropy=0.755404
# 2021-04-19 01:06:31,349 [INFO]  Epoch[10] Train-cross-entropy=0.755404
# Epoch[10] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:31,350 [INFO]  Epoch[10] Train-DGN-accuracy=0.752841
# Epoch[10] Time cost=0.335
# 2021-04-19 01:06:31,352 [INFO]  Epoch[10] Time cost=0.335
# Saved checkpoint to "imputer_model/model-0010.params"
# 2021-04-19 01:06:31,360 [INFO]  Saved checkpoint to "imputer_model/model-0010.params"
# Epoch[10] Validation-cross-entropy=0.700353
# 2021-04-19 01:06:31,406 [INFO]  Epoch[10] Validation-cross-entropy=0.700353
# Epoch[10] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:31,410 [INFO]  Epoch[10] Validation-DGN-accuracy=0.791667
# Epoch[11] Batch [0-11]	Speed: 1266.46 samples/sec	cross-entropy=0.812038	DGN-accuracy=0.713542
# 2021-04-19 01:06:31,570 [INFO]  Epoch[11] Batch [0-11]	Speed: 1266.46 samples/sec	cross-entropy=0.812038	DGN-accuracy=0.713542
# Epoch[11] Train-cross-entropy=0.752537
# 2021-04-19 01:06:31,707 [INFO]  Epoch[11] Train-cross-entropy=0.752537
# Epoch[11] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:31,709 [INFO]  Epoch[11] Train-DGN-accuracy=0.752841
# Epoch[11] Time cost=0.298
# 2021-04-19 01:06:31,710 [INFO]  Epoch[11] Time cost=0.298
# Saved checkpoint to "imputer_model/model-0011.params"
# 2021-04-19 01:06:31,720 [INFO]  Saved checkpoint to "imputer_model/model-0011.params"
# Epoch[11] Validation-cross-entropy=0.699111
# 2021-04-19 01:06:31,760 [INFO]  Epoch[11] Validation-cross-entropy=0.699111
# Epoch[11] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:31,762 [INFO]  Epoch[11] Validation-DGN-accuracy=0.791667
# Epoch[12] Batch [0-11]	Speed: 1242.71 samples/sec	cross-entropy=0.809106	DGN-accuracy=0.713542
# 2021-04-19 01:06:31,922 [INFO]  Epoch[12] Batch [0-11]	Speed: 1242.71 samples/sec	cross-entropy=0.809106	DGN-accuracy=0.713542
# Epoch[12] Train-cross-entropy=0.749818
# 2021-04-19 01:06:32,076 [INFO]  Epoch[12] Train-cross-entropy=0.749818
# Epoch[12] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:32,078 [INFO]  Epoch[12] Train-DGN-accuracy=0.752841
# Epoch[12] Time cost=0.316
# 2021-04-19 01:06:32,080 [INFO]  Epoch[12] Time cost=0.316
# Saved checkpoint to "imputer_model/model-0012.params"
# 2021-04-19 01:06:32,089 [INFO]  Saved checkpoint to "imputer_model/model-0012.params"
# Epoch[12] Validation-cross-entropy=0.697936
# 2021-04-19 01:06:32,131 [INFO]  Epoch[12] Validation-cross-entropy=0.697936
# Epoch[12] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:32,132 [INFO]  Epoch[12] Validation-DGN-accuracy=0.791667
# Epoch[13] Batch [0-11]	Speed: 1017.13 samples/sec	cross-entropy=0.806430	DGN-accuracy=0.713542
# 2021-04-19 01:06:32,326 [INFO]  Epoch[13] Batch [0-11]	Speed: 1017.13 samples/sec	cross-entropy=0.806430	DGN-accuracy=0.713542
# Epoch[13] Train-cross-entropy=0.747320
# 2021-04-19 01:06:32,466 [INFO]  Epoch[13] Train-cross-entropy=0.747320
# Epoch[13] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:32,467 [INFO]  Epoch[13] Train-DGN-accuracy=0.752841
# Epoch[13] Time cost=0.335
# 2021-04-19 01:06:32,469 [INFO]  Epoch[13] Time cost=0.335
# Saved checkpoint to "imputer_model/model-0013.params"
# 2021-04-19 01:06:32,480 [INFO]  Saved checkpoint to "imputer_model/model-0013.params"
# Epoch[13] Validation-cross-entropy=0.696934
# 2021-04-19 01:06:32,524 [INFO]  Epoch[13] Validation-cross-entropy=0.696934
# Epoch[13] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:32,525 [INFO]  Epoch[13] Validation-DGN-accuracy=0.791667
# Epoch[14] Batch [0-11]	Speed: 1023.22 samples/sec	cross-entropy=0.803879	DGN-accuracy=0.713542
# 2021-04-19 01:06:32,718 [INFO]  Epoch[14] Batch [0-11]	Speed: 1023.22 samples/sec	cross-entropy=0.803879	DGN-accuracy=0.713542
# Epoch[14] Train-cross-entropy=0.744805
# 2021-04-19 01:06:32,855 [INFO]  Epoch[14] Train-cross-entropy=0.744805
# Epoch[14] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:32,857 [INFO]  Epoch[14] Train-DGN-accuracy=0.752841
# Epoch[14] Time cost=0.332
# 2021-04-19 01:06:32,859 [INFO]  Epoch[14] Time cost=0.332
# Saved checkpoint to "imputer_model/model-0014.params"
# 2021-04-19 01:06:32,866 [INFO]  Saved checkpoint to "imputer_model/model-0014.params"
# Epoch[14] Validation-cross-entropy=0.695827
# 2021-04-19 01:06:32,909 [INFO]  Epoch[14] Validation-cross-entropy=0.695827
# Epoch[14] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:32,912 [INFO]  Epoch[14] Validation-DGN-accuracy=0.791667
# Epoch[15] Batch [0-11]	Speed: 1000.58 samples/sec	cross-entropy=0.801560	DGN-accuracy=0.713542
# 2021-04-19 01:06:33,108 [INFO]  Epoch[15] Batch [0-11]	Speed: 1000.58 samples/sec	cross-entropy=0.801560	DGN-accuracy=0.713542
# Epoch[15] Train-cross-entropy=0.742537
# 2021-04-19 01:06:33,251 [INFO]  Epoch[15] Train-cross-entropy=0.742537
# Epoch[15] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:33,253 [INFO]  Epoch[15] Train-DGN-accuracy=0.752841
# Epoch[15] Time cost=0.343
# 2021-04-19 01:06:33,256 [INFO]  Epoch[15] Time cost=0.343
# Saved checkpoint to "imputer_model/model-0015.params"
# 2021-04-19 01:06:33,264 [INFO]  Saved checkpoint to "imputer_model/model-0015.params"
# Epoch[15] Validation-cross-entropy=0.694765
# 2021-04-19 01:06:33,320 [INFO]  Epoch[15] Validation-cross-entropy=0.694765
# Epoch[15] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:33,322 [INFO]  Epoch[15] Validation-DGN-accuracy=0.791667
# Epoch[16] Batch [0-11]	Speed: 1216.46 samples/sec	cross-entropy=0.799305	DGN-accuracy=0.713542
# 2021-04-19 01:06:33,487 [INFO]  Epoch[16] Batch [0-11]	Speed: 1216.46 samples/sec	cross-entropy=0.799305	DGN-accuracy=0.713542
# Epoch[16] Train-cross-entropy=0.740256
# 2021-04-19 01:06:33,645 [INFO]  Epoch[16] Train-cross-entropy=0.740256
# Epoch[16] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:33,646 [INFO]  Epoch[16] Train-DGN-accuracy=0.752841
# Epoch[16] Time cost=0.323
# 2021-04-19 01:06:33,648 [INFO]  Epoch[16] Time cost=0.323
# Saved checkpoint to "imputer_model/model-0016.params"
# 2021-04-19 01:06:33,655 [INFO]  Saved checkpoint to "imputer_model/model-0016.params"
# Epoch[16] Validation-cross-entropy=0.693582
# 2021-04-19 01:06:33,706 [INFO]  Epoch[16] Validation-cross-entropy=0.693582
# Epoch[16] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:33,709 [INFO]  Epoch[16] Validation-DGN-accuracy=0.791667
# Epoch[17] Batch [0-11]	Speed: 952.27 samples/sec	cross-entropy=0.797111	DGN-accuracy=0.713542
# 2021-04-19 01:06:33,915 [INFO]  Epoch[17] Batch [0-11]	Speed: 952.27 samples/sec	cross-entropy=0.797111	DGN-accuracy=0.713542
# Epoch[17] Train-cross-entropy=0.738075
# 2021-04-19 01:06:34,055 [INFO]  Epoch[17] Train-cross-entropy=0.738075
# Epoch[17] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:34,057 [INFO]  Epoch[17] Train-DGN-accuracy=0.752841
# Epoch[17] Time cost=0.348
# 2021-04-19 01:06:34,059 [INFO]  Epoch[17] Time cost=0.348
# Saved checkpoint to "imputer_model/model-0017.params"
# 2021-04-19 01:06:34,067 [INFO]  Saved checkpoint to "imputer_model/model-0017.params"
# Epoch[17] Validation-cross-entropy=0.692616
# 2021-04-19 01:06:34,111 [INFO]  Epoch[17] Validation-cross-entropy=0.692616
# Epoch[17] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:34,113 [INFO]  Epoch[17] Validation-DGN-accuracy=0.791667
# Epoch[18] Batch [0-11]	Speed: 996.22 samples/sec	cross-entropy=0.794910	DGN-accuracy=0.718750
# 2021-04-19 01:06:34,310 [INFO]  Epoch[18] Batch [0-11]	Speed: 996.22 samples/sec	cross-entropy=0.794910	DGN-accuracy=0.718750
# Epoch[18] Train-cross-entropy=0.735817
# 2021-04-19 01:06:34,439 [INFO]  Epoch[18] Train-cross-entropy=0.735817
# Epoch[18] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:34,440 [INFO]  Epoch[18] Train-DGN-accuracy=0.755682
# Epoch[18] Time cost=0.329
# 2021-04-19 01:06:34,443 [INFO]  Epoch[18] Time cost=0.329
# Saved checkpoint to "imputer_model/model-0018.params"
# 2021-04-19 01:06:34,449 [INFO]  Saved checkpoint to "imputer_model/model-0018.params"
# Epoch[18] Validation-cross-entropy=0.691564
# 2021-04-19 01:06:34,493 [INFO]  Epoch[18] Validation-cross-entropy=0.691564
# Epoch[18] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:34,495 [INFO]  Epoch[18] Validation-DGN-accuracy=0.791667
# Epoch[19] Batch [0-11]	Speed: 1037.78 samples/sec	cross-entropy=0.792938	DGN-accuracy=0.718750
# 2021-04-19 01:06:34,686 [INFO]  Epoch[19] Batch [0-11]	Speed: 1037.78 samples/sec	cross-entropy=0.792938	DGN-accuracy=0.718750
# Epoch[19] Train-cross-entropy=0.733802
# 2021-04-19 01:06:34,818 [INFO]  Epoch[19] Train-cross-entropy=0.733802
# Epoch[19] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:34,819 [INFO]  Epoch[19] Train-DGN-accuracy=0.755682
# Epoch[19] Time cost=0.325
# 2021-04-19 01:06:34,821 [INFO]  Epoch[19] Time cost=0.325
# Saved checkpoint to "imputer_model/model-0019.params"
# 2021-04-19 01:06:34,832 [INFO]  Saved checkpoint to "imputer_model/model-0019.params"
# Epoch[19] Validation-cross-entropy=0.690729
# 2021-04-19 01:06:34,874 [INFO]  Epoch[19] Validation-cross-entropy=0.690729
# Epoch[19] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:34,876 [INFO]  Epoch[19] Validation-DGN-accuracy=0.791667
# Epoch[20] Batch [0-11]	Speed: 1188.55 samples/sec	cross-entropy=0.790923	DGN-accuracy=0.718750
# 2021-04-19 01:06:35,046 [INFO]  Epoch[20] Batch [0-11]	Speed: 1188.55 samples/sec	cross-entropy=0.790923	DGN-accuracy=0.718750
# Epoch[20] Train-cross-entropy=0.731808
# 2021-04-19 01:06:35,189 [INFO]  Epoch[20] Train-cross-entropy=0.731808
# Epoch[20] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:35,190 [INFO]  Epoch[20] Train-DGN-accuracy=0.755682
# Epoch[20] Time cost=0.315
# 2021-04-19 01:06:35,193 [INFO]  Epoch[20] Time cost=0.315
# Saved checkpoint to "imputer_model/model-0020.params"
# 2021-04-19 01:06:35,200 [INFO]  Saved checkpoint to "imputer_model/model-0020.params"
# Epoch[20] Validation-cross-entropy=0.689903
# 2021-04-19 01:06:35,240 [INFO]  Epoch[20] Validation-cross-entropy=0.689903
# Epoch[20] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:35,242 [INFO]  Epoch[20] Validation-DGN-accuracy=0.791667
# Epoch[21] Batch [0-11]	Speed: 1102.82 samples/sec	cross-entropy=0.789168	DGN-accuracy=0.718750
# 2021-04-19 01:06:35,427 [INFO]  Epoch[21] Batch [0-11]	Speed: 1102.82 samples/sec	cross-entropy=0.789168	DGN-accuracy=0.718750
# Epoch[21] Train-cross-entropy=0.729979
# 2021-04-19 01:06:35,588 [INFO]  Epoch[21] Train-cross-entropy=0.729979
# Epoch[21] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:35,589 [INFO]  Epoch[21] Train-DGN-accuracy=0.755682
# Epoch[21] Time cost=0.348
# 2021-04-19 01:06:35,591 [INFO]  Epoch[21] Time cost=0.348
# Saved checkpoint to "imputer_model/model-0021.params"
# 2021-04-19 01:06:35,598 [INFO]  Saved checkpoint to "imputer_model/model-0021.params"
# Epoch[21] Validation-cross-entropy=0.689229
# 2021-04-19 01:06:35,645 [INFO]  Epoch[21] Validation-cross-entropy=0.689229
# Epoch[21] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:35,647 [INFO]  Epoch[21] Validation-DGN-accuracy=0.791667
# Epoch[22] Batch [0-11]	Speed: 1062.39 samples/sec	cross-entropy=0.787370	DGN-accuracy=0.718750
# 2021-04-19 01:06:35,833 [INFO]  Epoch[22] Batch [0-11]	Speed: 1062.39 samples/sec	cross-entropy=0.787370	DGN-accuracy=0.718750
# Epoch[22] Train-cross-entropy=0.728023
# 2021-04-19 01:06:36,010 [INFO]  Epoch[22] Train-cross-entropy=0.728023
# Epoch[22] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:36,012 [INFO]  Epoch[22] Train-DGN-accuracy=0.755682
# Epoch[22] Time cost=0.365
# 2021-04-19 01:06:36,013 [INFO]  Epoch[22] Time cost=0.365
# Saved checkpoint to "imputer_model/model-0022.params"
# 2021-04-19 01:06:36,021 [INFO]  Saved checkpoint to "imputer_model/model-0022.params"
# Epoch[22] Validation-cross-entropy=0.688316
# 2021-04-19 01:06:36,058 [INFO]  Epoch[22] Validation-cross-entropy=0.688316
# Epoch[22] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:36,060 [INFO]  Epoch[22] Validation-DGN-accuracy=0.791667
# Epoch[23] Batch [0-11]	Speed: 1043.46 samples/sec	cross-entropy=0.785847	DGN-accuracy=0.713542
# 2021-04-19 01:06:36,251 [INFO]  Epoch[23] Batch [0-11]	Speed: 1043.46 samples/sec	cross-entropy=0.785847	DGN-accuracy=0.713542
# Epoch[23] Train-cross-entropy=0.726380
# 2021-04-19 01:06:36,422 [INFO]  Epoch[23] Train-cross-entropy=0.726380
# Epoch[23] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:36,423 [INFO]  Epoch[23] Train-DGN-accuracy=0.752841
# Epoch[23] Time cost=0.361
# 2021-04-19 01:06:36,425 [INFO]  Epoch[23] Time cost=0.361
# Saved checkpoint to "imputer_model/model-0023.params"
# 2021-04-19 01:06:36,436 [INFO]  Saved checkpoint to "imputer_model/model-0023.params"
# Epoch[23] Validation-cross-entropy=0.687383
# 2021-04-19 01:06:36,490 [INFO]  Epoch[23] Validation-cross-entropy=0.687383
# Epoch[23] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:36,492 [INFO]  Epoch[23] Validation-DGN-accuracy=0.791667
# Epoch[24] Batch [0-11]	Speed: 1008.84 samples/sec	cross-entropy=0.784040	DGN-accuracy=0.713542
# 2021-04-19 01:06:36,690 [INFO]  Epoch[24] Batch [0-11]	Speed: 1008.84 samples/sec	cross-entropy=0.784040	DGN-accuracy=0.713542
# Epoch[24] Train-cross-entropy=0.724485
# 2021-04-19 01:06:36,855 [INFO]  Epoch[24] Train-cross-entropy=0.724485
# Epoch[24] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:36,856 [INFO]  Epoch[24] Train-DGN-accuracy=0.752841
# Epoch[24] Time cost=0.365
# 2021-04-19 01:06:36,858 [INFO]  Epoch[24] Time cost=0.365
# Saved checkpoint to "imputer_model/model-0024.params"
# 2021-04-19 01:06:36,866 [INFO]  Saved checkpoint to "imputer_model/model-0024.params"
# Epoch[24] Validation-cross-entropy=0.686588
# 2021-04-19 01:06:36,905 [INFO]  Epoch[24] Validation-cross-entropy=0.686588
# Epoch[24] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:36,909 [INFO]  Epoch[24] Validation-DGN-accuracy=0.791667
# Epoch[25] Batch [0-11]	Speed: 1019.59 samples/sec	cross-entropy=0.782603	DGN-accuracy=0.713542
# 2021-04-19 01:06:37,107 [INFO]  Epoch[25] Batch [0-11]	Speed: 1019.59 samples/sec	cross-entropy=0.782603	DGN-accuracy=0.713542
# Epoch[25] Train-cross-entropy=0.722899
# 2021-04-19 01:06:37,278 [INFO]  Epoch[25] Train-cross-entropy=0.722899
# Epoch[25] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:37,280 [INFO]  Epoch[25] Train-DGN-accuracy=0.752841
# Epoch[25] Time cost=0.368
# 2021-04-19 01:06:37,282 [INFO]  Epoch[25] Time cost=0.368
# Saved checkpoint to "imputer_model/model-0025.params"
# 2021-04-19 01:06:37,290 [INFO]  Saved checkpoint to "imputer_model/model-0025.params"
# Epoch[25] Validation-cross-entropy=0.686058
# 2021-04-19 01:06:37,332 [INFO]  Epoch[25] Validation-cross-entropy=0.686058
# Epoch[25] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:37,333 [INFO]  Epoch[25] Validation-DGN-accuracy=0.791667
# Epoch[26] Batch [0-11]	Speed: 1184.10 samples/sec	cross-entropy=0.780930	DGN-accuracy=0.713542
# 2021-04-19 01:06:37,501 [INFO]  Epoch[26] Batch [0-11]	Speed: 1184.10 samples/sec	cross-entropy=0.780930	DGN-accuracy=0.713542
# Epoch[26] Train-cross-entropy=0.721142
# 2021-04-19 01:06:37,654 [INFO]  Epoch[26] Train-cross-entropy=0.721142
# Epoch[26] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:37,656 [INFO]  Epoch[26] Train-DGN-accuracy=0.752841
# Epoch[26] Time cost=0.324
# 2021-04-19 01:06:37,658 [INFO]  Epoch[26] Time cost=0.324
# Saved checkpoint to "imputer_model/model-0026.params"
# 2021-04-19 01:06:37,666 [INFO]  Saved checkpoint to "imputer_model/model-0026.params"
# Epoch[26] Validation-cross-entropy=0.685376
# 2021-04-19 01:06:37,704 [INFO]  Epoch[26] Validation-cross-entropy=0.685376
# Epoch[26] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:37,707 [INFO]  Epoch[26] Validation-DGN-accuracy=0.791667
# Epoch[27] Batch [0-11]	Speed: 1251.58 samples/sec	cross-entropy=0.779398	DGN-accuracy=0.713542
# 2021-04-19 01:06:37,867 [INFO]  Epoch[27] Batch [0-11]	Speed: 1251.58 samples/sec	cross-entropy=0.779398	DGN-accuracy=0.713542
# Epoch[27] Train-cross-entropy=0.719565
# 2021-04-19 01:06:38,007 [INFO]  Epoch[27] Train-cross-entropy=0.719565
# Epoch[27] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:38,009 [INFO]  Epoch[27] Train-DGN-accuracy=0.752841
# Epoch[27] Time cost=0.300
# 2021-04-19 01:06:38,011 [INFO]  Epoch[27] Time cost=0.300
# Saved checkpoint to "imputer_model/model-0027.params"
# 2021-04-19 01:06:38,021 [INFO]  Saved checkpoint to "imputer_model/model-0027.params"
# Epoch[27] Validation-cross-entropy=0.684747
# 2021-04-19 01:06:38,061 [INFO]  Epoch[27] Validation-cross-entropy=0.684747
# Epoch[27] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:38,063 [INFO]  Epoch[27] Validation-DGN-accuracy=0.791667
# Epoch[28] Batch [0-11]	Speed: 1218.35 samples/sec	cross-entropy=0.777866	DGN-accuracy=0.713542
# 2021-04-19 01:06:38,229 [INFO]  Epoch[28] Batch [0-11]	Speed: 1218.35 samples/sec	cross-entropy=0.777866	DGN-accuracy=0.713542
# Epoch[28] Train-cross-entropy=0.717969
# 2021-04-19 01:06:38,370 [INFO]  Epoch[28] Train-cross-entropy=0.717969
# Epoch[28] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:38,372 [INFO]  Epoch[28] Train-DGN-accuracy=0.752841
# Epoch[28] Time cost=0.309
# 2021-04-19 01:06:38,374 [INFO]  Epoch[28] Time cost=0.309
# Saved checkpoint to "imputer_model/model-0028.params"
# 2021-04-19 01:06:38,381 [INFO]  Saved checkpoint to "imputer_model/model-0028.params"
# Epoch[28] Validation-cross-entropy=0.684073
# 2021-04-19 01:06:38,424 [INFO]  Epoch[28] Validation-cross-entropy=0.684073
# Epoch[28] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:38,426 [INFO]  Epoch[28] Validation-DGN-accuracy=0.791667
# Epoch[29] Batch [0-11]	Speed: 1256.54 samples/sec	cross-entropy=0.776467	DGN-accuracy=0.713542
# 2021-04-19 01:06:38,587 [INFO]  Epoch[29] Batch [0-11]	Speed: 1256.54 samples/sec	cross-entropy=0.776467	DGN-accuracy=0.713542
# Epoch[29] Train-cross-entropy=0.716449
# 2021-04-19 01:06:38,725 [INFO]  Epoch[29] Train-cross-entropy=0.716449
# Epoch[29] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:38,727 [INFO]  Epoch[29] Train-DGN-accuracy=0.752841
# Epoch[29] Time cost=0.302
# 2021-04-19 01:06:38,729 [INFO]  Epoch[29] Time cost=0.302
# Saved checkpoint to "imputer_model/model-0029.params"
# 2021-04-19 01:06:38,736 [INFO]  Saved checkpoint to "imputer_model/model-0029.params"
# Epoch[29] Validation-cross-entropy=0.683565
# 2021-04-19 01:06:38,775 [INFO]  Epoch[29] Validation-cross-entropy=0.683565
# Epoch[29] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:38,777 [INFO]  Epoch[29] Validation-DGN-accuracy=0.791667
# Epoch[30] Batch [0-11]	Speed: 1178.94 samples/sec	cross-entropy=0.774928	DGN-accuracy=0.713542
# 2021-04-19 01:06:38,949 [INFO]  Epoch[30] Batch [0-11]	Speed: 1178.94 samples/sec	cross-entropy=0.774928	DGN-accuracy=0.713542
# Epoch[30] Train-cross-entropy=0.714879
# 2021-04-19 01:06:39,082 [INFO]  Epoch[30] Train-cross-entropy=0.714879
# Epoch[30] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:39,084 [INFO]  Epoch[30] Train-DGN-accuracy=0.752841
# Epoch[30] Time cost=0.310
# 2021-04-19 01:06:39,089 [INFO]  Epoch[30] Time cost=0.310
# Saved checkpoint to "imputer_model/model-0030.params"
# 2021-04-19 01:06:39,098 [INFO]  Saved checkpoint to "imputer_model/model-0030.params"
# Epoch[30] Validation-cross-entropy=0.682999
# 2021-04-19 01:06:39,136 [INFO]  Epoch[30] Validation-cross-entropy=0.682999
# Epoch[30] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:39,138 [INFO]  Epoch[30] Validation-DGN-accuracy=0.791667
# Epoch[31] Batch [0-11]	Speed: 1145.48 samples/sec	cross-entropy=0.773565	DGN-accuracy=0.713542
# 2021-04-19 01:06:39,317 [INFO]  Epoch[31] Batch [0-11]	Speed: 1145.48 samples/sec	cross-entropy=0.773565	DGN-accuracy=0.713542
# Epoch[31] Train-cross-entropy=0.713438
# 2021-04-19 01:06:39,448 [INFO]  Epoch[31] Train-cross-entropy=0.713438
# Epoch[31] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:39,450 [INFO]  Epoch[31] Train-DGN-accuracy=0.752841
# Epoch[31] Time cost=0.315
# 2021-04-19 01:06:39,454 [INFO]  Epoch[31] Time cost=0.315
# Saved checkpoint to "imputer_model/model-0031.params"
# 2021-04-19 01:06:39,463 [INFO]  Saved checkpoint to "imputer_model/model-0031.params"
# Epoch[31] Validation-cross-entropy=0.682521
# 2021-04-19 01:06:39,510 [INFO]  Epoch[31] Validation-cross-entropy=0.682521
# Epoch[31] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:39,512 [INFO]  Epoch[31] Validation-DGN-accuracy=0.791667
# Epoch[32] Batch [0-11]	Speed: 989.89 samples/sec	cross-entropy=0.772101	DGN-accuracy=0.713542
# 2021-04-19 01:06:39,712 [INFO]  Epoch[32] Batch [0-11]	Speed: 989.89 samples/sec	cross-entropy=0.772101	DGN-accuracy=0.713542
# Epoch[32] Train-cross-entropy=0.711964
# 2021-04-19 01:06:39,873 [INFO]  Epoch[32] Train-cross-entropy=0.711964
# Epoch[32] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:39,875 [INFO]  Epoch[32] Train-DGN-accuracy=0.752841
# Epoch[32] Time cost=0.362
# 2021-04-19 01:06:39,876 [INFO]  Epoch[32] Time cost=0.362
# Saved checkpoint to "imputer_model/model-0032.params"
# 2021-04-19 01:06:39,882 [INFO]  Saved checkpoint to "imputer_model/model-0032.params"
# Epoch[32] Validation-cross-entropy=0.682506
# 2021-04-19 01:06:39,924 [INFO]  Epoch[32] Validation-cross-entropy=0.682506
# Epoch[32] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:39,927 [INFO]  Epoch[32] Validation-DGN-accuracy=0.791667
# Epoch[33] Batch [0-11]	Speed: 1211.87 samples/sec	cross-entropy=0.770719	DGN-accuracy=0.713542
# 2021-04-19 01:06:40,090 [INFO]  Epoch[33] Batch [0-11]	Speed: 1211.87 samples/sec	cross-entropy=0.770719	DGN-accuracy=0.713542
# Epoch[33] Train-cross-entropy=0.710555
# 2021-04-19 01:06:40,241 [INFO]  Epoch[33] Train-cross-entropy=0.710555
# Epoch[33] Train-DGN-accuracy=0.752841
# 2021-04-19 01:06:40,243 [INFO]  Epoch[33] Train-DGN-accuracy=0.752841
# Epoch[33] Time cost=0.314
# 2021-04-19 01:06:40,244 [INFO]  Epoch[33] Time cost=0.314
# Saved checkpoint to "imputer_model/model-0033.params"
# 2021-04-19 01:06:40,252 [INFO]  Saved checkpoint to "imputer_model/model-0033.params"
# Epoch[33] Validation-cross-entropy=0.682223
# 2021-04-19 01:06:40,298 [INFO]  Epoch[33] Validation-cross-entropy=0.682223
# Epoch[33] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:40,299 [INFO]  Epoch[33] Validation-DGN-accuracy=0.791667
# Epoch[34] Batch [0-11]	Speed: 1010.63 samples/sec	cross-entropy=0.769372	DGN-accuracy=0.718750
# 2021-04-19 01:06:40,492 [INFO]  Epoch[34] Batch [0-11]	Speed: 1010.63 samples/sec	cross-entropy=0.769372	DGN-accuracy=0.718750
# Epoch[34] Train-cross-entropy=0.709189
# 2021-04-19 01:06:40,643 [INFO]  Epoch[34] Train-cross-entropy=0.709189
# Epoch[34] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:40,645 [INFO]  Epoch[34] Train-DGN-accuracy=0.755682
# Epoch[34] Time cost=0.346
# 2021-04-19 01:06:40,647 [INFO]  Epoch[34] Time cost=0.346
# Saved checkpoint to "imputer_model/model-0034.params"
# 2021-04-19 01:06:40,652 [INFO]  Saved checkpoint to "imputer_model/model-0034.params"
# Epoch[34] Validation-cross-entropy=0.681888
# 2021-04-19 01:06:40,694 [INFO]  Epoch[34] Validation-cross-entropy=0.681888
# Epoch[34] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:40,696 [INFO]  Epoch[34] Validation-DGN-accuracy=0.791667
# Epoch[35] Batch [0-11]	Speed: 1142.69 samples/sec	cross-entropy=0.768014	DGN-accuracy=0.718750
# 2021-04-19 01:06:40,871 [INFO]  Epoch[35] Batch [0-11]	Speed: 1142.69 samples/sec	cross-entropy=0.768014	DGN-accuracy=0.718750
# Epoch[35] Train-cross-entropy=0.707875
# 2021-04-19 01:06:41,006 [INFO]  Epoch[35] Train-cross-entropy=0.707875
# Epoch[35] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:41,009 [INFO]  Epoch[35] Train-DGN-accuracy=0.755682
# Epoch[35] Time cost=0.313
# 2021-04-19 01:06:41,011 [INFO]  Epoch[35] Time cost=0.313
# Saved checkpoint to "imputer_model/model-0035.params"
# 2021-04-19 01:06:41,018 [INFO]  Saved checkpoint to "imputer_model/model-0035.params"
# Epoch[35] Validation-cross-entropy=0.681567
# 2021-04-19 01:06:41,063 [INFO]  Epoch[35] Validation-cross-entropy=0.681567
# Epoch[35] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:41,065 [INFO]  Epoch[35] Validation-DGN-accuracy=0.791667
# Epoch[36] Batch [0-11]	Speed: 1213.17 samples/sec	cross-entropy=0.766539	DGN-accuracy=0.718750
# 2021-04-19 01:06:41,229 [INFO]  Epoch[36] Batch [0-11]	Speed: 1213.17 samples/sec	cross-entropy=0.766539	DGN-accuracy=0.718750
# Epoch[36] Train-cross-entropy=0.706411
# 2021-04-19 01:06:41,363 [INFO]  Epoch[36] Train-cross-entropy=0.706411
# Epoch[36] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:41,364 [INFO]  Epoch[36] Train-DGN-accuracy=0.755682
# Epoch[36] Time cost=0.300
# 2021-04-19 01:06:41,366 [INFO]  Epoch[36] Time cost=0.300
# Saved checkpoint to "imputer_model/model-0036.params"
# 2021-04-19 01:06:41,371 [INFO]  Saved checkpoint to "imputer_model/model-0036.params"
# Epoch[36] Validation-cross-entropy=0.681202
# 2021-04-19 01:06:41,410 [INFO]  Epoch[36] Validation-cross-entropy=0.681202
# Epoch[36] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:41,412 [INFO]  Epoch[36] Validation-DGN-accuracy=0.791667
# Epoch[37] Batch [0-11]	Speed: 1128.16 samples/sec	cross-entropy=0.765559	DGN-accuracy=0.718750
# 2021-04-19 01:06:41,589 [INFO]  Epoch[37] Batch [0-11]	Speed: 1128.16 samples/sec	cross-entropy=0.765559	DGN-accuracy=0.718750
# Epoch[37] Train-cross-entropy=0.705277
# 2021-04-19 01:06:41,736 [INFO]  Epoch[37] Train-cross-entropy=0.705277
# Epoch[37] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:41,737 [INFO]  Epoch[37] Train-DGN-accuracy=0.755682
# Epoch[37] Time cost=0.326
# 2021-04-19 01:06:41,739 [INFO]  Epoch[37] Time cost=0.326
# Saved checkpoint to "imputer_model/model-0037.params"
# 2021-04-19 01:06:41,748 [INFO]  Saved checkpoint to "imputer_model/model-0037.params"
# Epoch[37] Validation-cross-entropy=0.681397
# 2021-04-19 01:06:41,788 [INFO]  Epoch[37] Validation-cross-entropy=0.681397
# Epoch[37] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:41,789 [INFO]  Epoch[37] Validation-DGN-accuracy=0.791667
# Epoch[38] Batch [0-11]	Speed: 1040.00 samples/sec	cross-entropy=0.763991	DGN-accuracy=0.718750
# 2021-04-19 01:06:41,982 [INFO]  Epoch[38] Batch [0-11]	Speed: 1040.00 samples/sec	cross-entropy=0.763991	DGN-accuracy=0.718750
# Epoch[38] Train-cross-entropy=0.703849
# 2021-04-19 01:06:42,140 [INFO]  Epoch[38] Train-cross-entropy=0.703849
# Epoch[38] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:42,142 [INFO]  Epoch[38] Train-DGN-accuracy=0.755682
# Epoch[38] Time cost=0.354
# 2021-04-19 01:06:42,146 [INFO]  Epoch[38] Time cost=0.354
# Saved checkpoint to "imputer_model/model-0038.params"
# 2021-04-19 01:06:42,152 [INFO]  Saved checkpoint to "imputer_model/model-0038.params"
# Epoch[38] Validation-cross-entropy=0.681413
# 2021-04-19 01:06:42,191 [INFO]  Epoch[38] Validation-cross-entropy=0.681413
# Epoch[38] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:42,193 [INFO]  Epoch[38] Validation-DGN-accuracy=0.791667
# Epoch[39] Batch [0-11]	Speed: 1164.55 samples/sec	cross-entropy=0.762623	DGN-accuracy=0.718750
# 2021-04-19 01:06:42,363 [INFO]  Epoch[39] Batch [0-11]	Speed: 1164.55 samples/sec	cross-entropy=0.762623	DGN-accuracy=0.718750
# Epoch[39] Train-cross-entropy=0.702468
# 2021-04-19 01:06:42,500 [INFO]  Epoch[39] Train-cross-entropy=0.702468
# Epoch[39] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:42,501 [INFO]  Epoch[39] Train-DGN-accuracy=0.755682
# Epoch[39] Time cost=0.309
# 2021-04-19 01:06:42,503 [INFO]  Epoch[39] Time cost=0.309
# Saved checkpoint to "imputer_model/model-0039.params"
# 2021-04-19 01:06:42,515 [INFO]  Saved checkpoint to "imputer_model/model-0039.params"
# Epoch[39] Validation-cross-entropy=0.681368
# 2021-04-19 01:06:42,557 [INFO]  Epoch[39] Validation-cross-entropy=0.681368
# Epoch[39] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:42,559 [INFO]  Epoch[39] Validation-DGN-accuracy=0.791667
# Epoch[40] Batch [0-11]	Speed: 1226.05 samples/sec	cross-entropy=0.761542	DGN-accuracy=0.718750
# 2021-04-19 01:06:42,719 [INFO]  Epoch[40] Batch [0-11]	Speed: 1226.05 samples/sec	cross-entropy=0.761542	DGN-accuracy=0.718750
# Epoch[40] Train-cross-entropy=0.701443
# 2021-04-19 01:06:42,867 [INFO]  Epoch[40] Train-cross-entropy=0.701443
# Epoch[40] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:42,868 [INFO]  Epoch[40] Train-DGN-accuracy=0.755682
# Epoch[40] Time cost=0.311
# 2021-04-19 01:06:42,871 [INFO]  Epoch[40] Time cost=0.311
# Saved checkpoint to "imputer_model/model-0040.params"
# 2021-04-19 01:06:42,877 [INFO]  Saved checkpoint to "imputer_model/model-0040.params"
# Epoch[40] Validation-cross-entropy=0.681531
# 2021-04-19 01:06:42,921 [INFO]  Epoch[40] Validation-cross-entropy=0.681531
# Epoch[40] Validation-DGN-accuracy=0.791667
# 2021-04-19 01:06:42,923 [INFO]  Epoch[40] Validation-DGN-accuracy=0.791667
# Epoch[41] Batch [0-11]	Speed: 1226.99 samples/sec	cross-entropy=0.760014	DGN-accuracy=0.718750
# 2021-04-19 01:06:43,090 [INFO]  Epoch[41] Batch [0-11]	Speed: 1226.99 samples/sec	cross-entropy=0.760014	DGN-accuracy=0.718750
# Epoch[41] Train-cross-entropy=0.700015
# 2021-04-19 01:06:43,222 [INFO]  Epoch[41] Train-cross-entropy=0.700015
# Epoch[41] Train-DGN-accuracy=0.755682
# 2021-04-19 01:06:43,223 [INFO]  Epoch[41] Train-DGN-accuracy=0.755682
# Epoch[41] Time cost=0.300
# 2021-04-19 01:06:43,225 [INFO]  Epoch[41] Time cost=0.300
# Saved checkpoint to "imputer_model/model-0041.params"
# 2021-04-19 01:06:43,235 [INFO]  Saved checkpoint to "imputer_model/model-0041.params"
# No improvement detected for 5 epochs compared to 0.681202232837677 last error obtained: 0.6813886165618896, stopping here
# 2021-04-19 01:06:43,269 [INFO]  No improvement detected for 5 epochs compared to 0.681202232837677 last error obtained: 0.6813886165618896, stopping here
#
# ========== done (16.268216609954834 s) fit model
# 2021-04-19 01:06:43,270 [INFO]
# ========== done (16.268216609954834 s) fit model
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE6
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE7
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE8
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE9
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE30
# Fitting model for column: PRE32
# Fitting model for column: PRE4
# Fitting model for column: PRE5
# Fitting model for column: AGE
#
# Outlier detection method: PyODKNNOutlierDetection, Outlier Detection Score: {'Precision': 0.85453216374269, 'Recall': 0.9330357142857143, 'F1-score': 0.8870192307692308, 'Accuracy': 0.9361702127659575}
# Imputation method: DatawigImputation, Imputation Score: {'Precision': nan, 'Recall': nan, 'F1-score': nan, 'Accuracy': nan, 'Mean Squared Error': 0.0265080316018372}
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Cleaner: (PyODKNNOutlierDetection, DatawigImputation): {'roc_auc_score': 0.6322115384615385, 'classification_report': {'F': {'precision': 0.8297872340425532, 'recall': 1.0, 'f1-score': 0.9069767441860465, 'support': 78}, 'T': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 16}, 'accuracy': 0.8297872340425532, 'macro avg': {'precision': 0.4148936170212766, 'recall': 0.5, 'f1-score': 0.45348837209302323, 'support': 94}, 'weighted avg': {'precision': 0.688546853779991, 'recall': 0.8297872340425532, 'f1-score': 0.7525977238990599, 'support': 94}}}
#
# Outlier detection method: PyODIsolationForestOutlierDetection, Outlier Detection Score: {'Precision': 0.6719348659003831, 'Recall': 0.8205357142857144, 'F1-score': 0.6730434782608696, 'Accuracy': 0.7446808510638298}
# Imputation method: MeanModeImputation, Imputation Score: {'Precision': nan, 'Recall': nan, 'F1-score': nan, 'Accuracy': nan, 'Mean Squared Error': 0.46485561323316577}
# Cleaner: (PyODIsolationForestOutlierDetection, MeanModeImputation): {'roc_auc_score': 0.6217948717948718, 'classification_report': {'F': {'precision': 0.8387096774193549, 'recall': 1.0, 'f1-score': 0.9122807017543859, 'support': 78}, 'T': {'precision': 1.0, 'recall': 0.0625, 'f1-score': 0.11764705882352941, 'support': 16}, 'accuracy': 0.8404255319148937, 'macro avg': {'precision': 0.9193548387096775, 'recall': 0.53125, 'f1-score': 0.5149638802889577, 'support': 94}, 'weighted avg': {'precision': 0.8661633493479753, 'recall': 0.8404255319148937, 'f1-score': 0.7770239114682825, 'support': 94}}}
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# Classifier for col: DGN reached 0.6966666666666667
# Classifier for col: PRE6 reached 0.8333333333333333
# Classifier for col: PRE7 reached 0.9299999999999999
# Classifier for col: PRE8 reached 0.8333333333333334
# Classifier for col: PRE9 reached 0.9299999999999999
# Classifier for col: PRE10 reached 0.9
# Classifier for col: PRE11 reached 0.87
# Classifier for col: PRE14 reached 0.5233333333333334
# Classifier for col: PRE17 reached 0.9266666666666667
# Classifier for col: PRE19 reached 0.9933333333333333
# Classifier for col: PRE25 reached 0.9833333333333334
# Classifier for col: PRE30 reached 0.8200000000000001
# Classifier for col: PRE32 reached 0.9866666666666666
# Regressor for col: PRE4/lower reached 0.2518246825968417
# Regressor for col: PRE4/median reached 0.7090769088830099
# Regressor for col: PRE4/upper reached 0.4700858585233926
# Regressor for col: PRE5/lower reached -0.05617432911489073
# Regressor for col: PRE5/median reached 0.04688510108324373
# Regressor for col: PRE5/upper reached -0.05024441520189636
# Regressor for col: AGE/lower reached -0.8181431279206954
# Regressor for col: AGE/median reached 0.037980547544004206
# Regressor for col: AGE/upper reached -1.011828408880574
# Imputed 35 values in column PRE4
# Imputed 28 values in column PRE5
# Imputed 26 values in column AGE
#
# Outlier detection method: PyODIsolationForestOutlierDetection, Outlier Detection Score: {'Precision': 0.6772397094430993, 'Recall': 0.8267857142857142, 'F1-score': 0.6825723094993392, 'Accuracy': 0.7553191489361702}
# Imputation method: SklearnImputation, Imputation Score: {'Precision': nan, 'Recall': nan, 'F1-score': nan, 'Accuracy': nan, 'Mean Squared Error': 0.3643532929711349}
# Cleaner: (PyODIsolationForestOutlierDetection, SklearnImputation): {'roc_auc_score': 0.6342147435897435, 'classification_report': {'F': {'precision': 0.8387096774193549, 'recall': 1.0, 'f1-score': 0.9122807017543859, 'support': 78}, 'T': {'precision': 1.0, 'recall': 0.0625, 'f1-score': 0.11764705882352941, 'support': 16}, 'accuracy': 0.8404255319148937, 'macro avg': {'precision': 0.9193548387096775, 'recall': 0.53125, 'f1-score': 0.5149638802889577, 'support': 94}, 'weighted avg': {'precision': 0.8661633493479753, 'recall': 0.8404255319148937, 'f1-score': 0.7770239114682825, 'support': 94}}}
# Fitting model for column: DGN
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE6
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE7
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE8
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE9
# Fitting model for column: PRE10
# Fitting model for column: PRE11
# Fitting model for column: PRE14
# Fitting model for column: PRE17
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE19
# Fitting model for column: PRE25
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fitting model for column: PRE30
# Fitting model for column: PRE32
# Fitting model for column: PRE4
# Fitting model for column: PRE5
# Fitting model for column: AGE
#
# Outlier detection method: PyODIsolationForestOutlierDetection, Outlier Detection Score: {'Precision': 0.675, 'Recall': 0.8375, 'F1-score': 0.6622443338861249, 'Accuracy': 0.723404255319149}
# Imputation method: DatawigImputation, Imputation Score: {'Precision': nan, 'Recall': nan, 'F1-score': nan, 'Accuracy': nan, 'Mean Squared Error': 0.36555904878949647}
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Cleaner: (PyODIsolationForestOutlierDetection, DatawigImputation): {'roc_auc_score': 0.6294070512820512, 'classification_report': {'F': {'precision': 0.8297872340425532, 'recall': 1.0, 'f1-score': 0.9069767441860465, 'support': 78}, 'T': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 16}, 'accuracy': 0.8297872340425532, 'macro avg': {'precision': 0.4148936170212766, 'recall': 0.5, 'f1-score': 0.45348837209302323, 'support': 94}, 'weighted avg': {'precision': 0.688546853779991, 'recall': 0.8297872340425532, 'f1-score': 0.7525977238990599, 'support': 94}}}
#
# Outlier detection method: PyODPCAOutlierDetection, Outlier Detection Score: {'Precision': 0.6575757575757576, 'Recall': 0.8017857142857143, 'F1-score': 0.6452830188679246, 'Accuracy': 0.7127659574468085}
# Imputation method: MeanModeImputation, Imputation Score: {'Precision': nan, 'Recall': nan, 'F1-score': nan, 'Accuracy': nan, 'Mean Squared Error': 0.409574559420426}
# Cleaner: (PyODPCAOutlierDetection, MeanModeImputation): {'roc_auc_score': 0.5805288461538461, 'classification_report': {'F': {'precision': 0.8387096774193549, 'recall': 1.0, 'f1-score': 0.9122807017543859, 'support': 78}, 'T': {'precision': 1.0, 'recall': 0.0625, 'f1-score': 0.11764705882352941, 'support': 16}, 'accuracy': 0.8404255319148937, 'macro avg': {'precision': 0.9193548387096775, 'recall': 0.53125, 'f1-score': 0.5149638802889577, 'support': 94}, 'weighted avg': {'precision': 0.8661633493479753, 'recall': 0.8404255319148937, 'f1-score': 0.7770239114682825, 'support': 94}}}
# /home/rupali/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# Classifier for col: DGN reached 0.7266666666666666
# Classifier for col: PRE6 reached 0.8733333333333333
# Classifier for col: PRE7 reached 0.95
# Classifier for col: PRE8 reached 0.85
# Classifier for col: PRE9 reached 0.95
# Classifier for col: PRE10 reached 0.8666666666666667
# Classifier for col: PRE11 reached 0.8500000000000001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-aae64be1b108> in <module>
#       7             for dataset in datasets:
#       8                 try:
# ----> 9                     ind_results[fraction].append(run_experiment(dataset, learner, param_grid, corruption, fraction, cleaners, 5))
#      10                 except ConnectionError:
#      11                     print(f'Connection refused for dataset: {dataset}')
#
# <ipython-input-4-49c1c4602e8c> in run_experiment(dataset_name, learner, param_grid, corruptions, fraction, cleaners, num_repetitions, categorical_precision_threshold, numerical_std_error_threshold)
#      32     ## cleaning
#      33     clean = Clean(df_train, df_corrupted, categorical_columns, numerical_columns, categorical_precision_threshold, numerical_std_error_threshold, ppp, ppp_model, cleaners)
# ---> 34     df_outliers, df_cleaned, corrupted_score_ppp, best_cleaning_score, cleaner_scores_ppp, summary_cleaners = clean(df_train, df_test, df_corrupted, cols_perturbed)
#      35
#      36     ## results
#
# ~/Documents/Master Thesis/jenga/jenga/cleaning/clean.py in __call__(self, df_train, df_test, df_corrupted, cols_perturbed)
#     109
#     110     def __call__(self, df_train, df_test, df_corrupted, cols_perturbed):
# --> 111         return self.get_cleaned(df_train, df_test, df_corrupted, cols_perturbed)
#
# ~/Documents/Master Thesis/jenga/jenga/cleaning/clean.py in get_cleaned(self, df_train, df_test, df_corrupted, cols_perturbed)
#      69         cleaning_scores_ppp = []
#      70         for cleaner in self.cleaners:
# ---> 71             df_outliers, df_cleaned = cleaner.apply_cleaner(df_train, df_corrupted)
#      72             outlier_detection_score, imputation_score = cleaner.cleaner_scores(df_test, df_corrupted, df_outliers, df_cleaned, cols_perturbed)
#      73             print(f"\nOutlier detection method: {cleaner.outlier_detection}, Outlier Detection Score: {outlier_detection_score}")
#
# ~/Documents/Master Thesis/jenga/jenga/cleaning/cleaner.py in apply_cleaner(self, df_train, df_corrupted)
#      26
#      27         # impute
# ---> 28         df_imputed = self.imputation(df_train, df_outliers[df_corrupted.columns], predictors)
#      29
#      30         return df_outliers, df_imputed
#
# ~/Documents/Master Thesis/jenga/jenga/cleaning/imputation.py in __call__(self, df_train, df_corrupted, predictors)
#     188
#     189     def __call__(self, df_train, df_corrupted, predictors):
# --> 190         return self.fit_transform(df_train, df_corrupted, predictors)
#     191
#     192
#
# ~/Documents/Master Thesis/jenga/jenga/cleaning/imputation.py in fit_transform(self, df_train, df_corrupted, predictors)
#     134
#     135                         search = GridSearchCV(pipeline, param_grid, cv=2, verbose=0, n_jobs=-1)
# --> 136                         predictors[col] = search.fit(df_train, df_train[col])
#     137
#     138                         print(f'Classifier for col: {col} reached {search.best_score_}')
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     680                               n_splits, n_candidates, n_candidates * n_splits))
#     681
# --> 682                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     683                                                        X, y,
#     684                                                        train=train, test=test,
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
save_obj(ind_results, "gaussian/ind_results")

# %% [markdown]
# ## Scaling

# %%
corruptions = [[Scaling]]

# %%
ind_results = {}

for fraction in fractions:
    ind_results[fraction] = []
    for learner, param_grid in models.items():
        for corruption in corruptions:
            for dataset in datasets:
                try:
                    ind_results[fraction].append(run_experiment(dataset, learner, param_grid, corruption, fraction, cleaners, 5))
                except ConnectionError:
                    print(f'Connection refused for dataset: {dataset}')
                    continue
                except ValueError:
                    print("Something went wrong with a value :(")
                    continue

# %%
save_obj(ind_results, "scaling/ind_results")

# %% [markdown]
# ## Missing

# %%
corruptions = [[MissingValues]]

# %%
ind_results = {}

for fraction in fractions:
    ind_results[fraction] = []
    for learner, param_grid in models.items():
        for corruption in corruptions:
            for dataset in datasets:
                try:
                    ind_results[fraction].append(run_experiment(dataset, learner, param_grid, corruption, fraction, cleaners, 5))
                except ConnectionError:
                    print(f'Connection refused for dataset: {dataset}')
                    continue
                except ValueError:
                    print("Something went wrong with a value :(")
                    continue

# %%
save_obj(ind_results, "missing/ind_results")

# %% [markdown]
# ## Categorical Shift

# %%
corruptions = [[CategoricalShift]]

# %%
ind_results = {}

for fraction in fractions:
    ind_results[fraction] = []
    for learner, param_grid in models.items():
        for corruption in corruptions:
            for dataset in datasets:
                try:
                    ind_results[fraction].append(run_experiment(dataset, learner, param_grid, corruption, fraction, cleaners, 5))
                except ConnectionError:
                    print(f'Connection refused for dataset: {dataset}')
                    continue
                except ValueError:
                    print("Something went wrong with a value :(")
                    continue

# %%
save_obj(ind_results, "categorical_shift/ind_results")
